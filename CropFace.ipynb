# %% [markdown]
# <a href="https://colab.research.google.com/github/PRAN20/Crop-Face-Reading/blob/main/CropFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Header Files**

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading Face Data**

# %%
img = cv2.imread('face.jpg')

# %%
plt.title('ORIGINAL IMAGE')
plt.imshow(img)

# %% [markdown]
# **CROP IMAGE**

# %%
cropped = img[20:100, 20:80]

# %%
plt.title('ORIGINAL IMAGE')
plt.imshow(cropped)
